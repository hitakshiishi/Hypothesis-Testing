# %% [markdown]
# Task 1: Category Performance Analysis
#
# A bar chart is used to compare total sales by category. The category with the highest bar represents the top-performing category.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Task 2: Sales Trend Analysis
#
# A line chart is used to analyze sales trends over time. It helps identify peak and slow periods.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Task 3: Regional Contribution Analysis
#
# This chart shows region-wise sales contribution. The region with the highest value contributes the most.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# TASK 4: Profitability Analysis
#
# This chart shows the relationship between sales and profit. It helps identify loss-making or low-profit orders.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# TASK 5: Business Growth
#
# This chart shows cumulative sales growth over time and helps evaluate overall business performance.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# TASK 6: Category vs Region
#
# This visualization compares category performance across regions to identify strong and weak markets.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# TASK 7: Product Prioritization
#
# This chart analyzes products based on sales, profit, and quantity to identify priority products.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# TASK 8: Dashboard Creation
#
# An interactive dashboard is created by combining multiple visualizations and applying filters such as region or category.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q9: Chart Selection Justification
#
# Different charts are used based on data type. Bar charts compare categories, line charts show trends over time, and scatter plots show relationships between variables. This helps in better data understanding.

# %% [markdown]
# Q10: Business Insight Summary
#
# Technology category may generate highest sales and profit
# Some regions may show lower performance
#
# These insights help management focus on profitable areas and improve weak regions.
