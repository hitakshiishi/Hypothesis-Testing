# %% [markdown]
# Q 1. Create a calculated column TotalPrice using Quantity .
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q 2.Create a calculated column .
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q 3. Create a measure .
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q 4. Using DAX, create a measure that calculates cumulative Year-to-Date (YTD) Sales based on the Order
# Date.
#
# - YTD Sales = TOTALYTD(SUM([SalesAmount]), [OrderDate])

# %% [markdown]
# Q 5.Using DAX, create a measure to rank each product according to its Total Sales, with the highest-selling
# product ranked first.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q 6.Create a calculated column classifying orders as “High Value” if sales > 2000, else “Low Value”.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q 7.Create a measure to calculate total sales from the Online channel only.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q 8. Create a measure called "Date Difference" that calculates the number of days between the latest  Order
# Date and today's date using the DATEDIFF function.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
