# %% [markdown]
# Q  1.Write a formula to check if the marks in cell are greater than or equal to 40. If yes, return , otherwise
# .
# - =IF(B2>=40,"Pass","Fail")
#
# ![Screenshot (80).png](data:image/png;base64,...)

# %% [markdown]
# Q 2. A company gives a bonus  if sales are above 40,000 and attendance is greater than or equal to 90%. Write a
# formula to calculate whether the employee will get a bonus or not .
#
# - Condition:
#
#     Sales > 40000
#
#     Attendance ≥ 90%
#
# - Assume:
#
#   Sales → B2
#
#   Attendance → C2
# - =IF(AND(B2>40000,C2>=90),"Bonus","No Bonus")
#
# ![Screenshot (84).png](data:image/png;base64,...)

# %% [markdown]
# Q 3.write a nested IF formula:
# If marks in are ≥ 90 → , ≥ 75 → , ≥ 50 → , otherwise . B2 "A" "B" "C" "Fail.
#
# - =IF(B2>=90,"A",
#
#     IF(B2>=75,"B",
#
#       IF(B2>=50,"C","Fail")))
#
#  ![Screenshot (85).png](data:image/png;base64,...)

# %% [markdown]
# Q 4. find the Department of Employee ID = E103. Also explain which LOOKUP function is used and why?
#
# - Table:
# A2:C5 (EmpID, Name, Department)
#
# =VLOOKUP("E103",A2:C5,3,FALSE)
#
# Answer: Finance
#
# Uses VLOOKUP because EmpID is in first column.
#
# ![Screenshot (86).png](data:image/png;base64,...)

# %% [markdown]
# Q 5.A company has set the following commission structure for its sales team:
# If a salesperson achieves sales of ₹45,000, use the VLOOKUP function to determine the commission rate
# applicable.
#
# - =VLOOKUP(45000,A2:B5,2,TRUE)
#
# ![Screenshot (81).png](data:image/png;base64,...)

# %% [markdown]
# Q 6.The HR department maintains the following leave records of employees:onus or not .
#
# - Condition:
# If Leaves Taken > Leaves Allowed → "Exceeded"
# Otherwise → "OK"
#
#  Leaves Taken → B2
#
#  Leaves Allowed → C2
#
#  - =IF(B2>C2,"Exceeded","OK")

# %% [markdown]
# Q 7.Find the salary of EmpID = E105 using INDEX-MATCH Function.
#
# ![Screenshot (82).png](data:image/png;base64,...)

# %% [markdown]
# Q 8.use the XLOOKUP function to find the Department of the employee with Emp ID = E303.
#
# ![Screenshot (83).png](data:image/png;base64,...)
